# %% [markdown]
# <a href="https://colab.research.google.com/github/tlcpack/python_congress/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from requests.auth import HTTPBasicAuth
import requests
import json

url = "https://api.propublica.org/congress/v1/116/house/members.json"
headers = {"X-API-Key": "LJgQYwDfuk9k4KkmrZj1DcbU6AJ5nawhLGaiN5oM"}
# auth = HTTPBasicAuth("X-API-Key", "LJgQYwDfuk9k4KkmrZj1DcbU6AJ5nawhLGaiN5oM")

req = requests.get(url, headers=headers)
# for i in req:
#   print(i)
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# jprint(req.json())
# jprint(req.json()['results'][0]['members'])

members = req.json()['results'][0]['members']

by_state = sorted(members, key=lambda members: members['state'])
for member in by_state:
  if member['party'] == 'D':
    print(member['state'] + ': '  + member['first_name'] + ' ' + member['last_name'])
# Out:
# AL: Terri Sewell
# AZ: Ruben Gallego
# AZ: Raúl Grijalva
# AZ: Ann Kirkpatrick
# AZ: Tom O'Halleran
# AZ: Greg Stanton
# CA: Pete Aguilar
# CA: Nanette Barragán
# CA: Karen Bass
# CA: Ami Bera
# CA: Julia Brownley
# CA: Salud Carbajal
# CA: Tony Cárdenas
# CA: Judy Chu
# CA: Gilbert Cisneros
# CA: J. Correa
# CA: Jim Costa
# CA: TJ Cox
# CA: Susan Davis
# CA: Mark DeSaulnier
# CA: Anna Eshoo
# CA: John Garamendi
# CA: Jimmy Gomez
# CA: Josh Harder
# CA: Katie Hill
# CA: Jared Huffman
# CA: Ro Khanna
# CA: Barbara Lee
# CA: Mike Levin
# CA: Ted Lieu
# CA: Zoe Lofgren
# CA: Alan Lowenthal
# CA: Doris Matsui
# CA: Jerry McNerney
# CA: Grace Napolitano
# CA: Jimmy Panetta
# CA: Nancy Pelosi
# CA: Scott Peters
# CA: Katie Porter
# CA: Harley Rouda
# CA: Lucille Roybal-Allard
# CA: Raul Ruiz
# CA: Linda Sánchez
# CA: Adam Schiff
# CA: Brad Sherman
# CA: Jackie Speier
# CA: Eric Swalwell
# CA: Mark Takano
# CA: Mike Thompson
# CA: Norma Torres
# CA: Juan Vargas
# CA: Maxine Waters
# ...
